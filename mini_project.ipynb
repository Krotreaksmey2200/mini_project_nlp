# %% [markdown]
# ### scrap corpus

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2026.2.25)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4) (2.8.3)

# %%
import requests
from bs4 import BeautifulSoup

def fetch_wikipedia_article(url, output_file="wikipedia1.txt"):
    try:
        # កំណត់ headers (ជៀសវាង block)
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }

        # ទាញយក HTML
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        # Parse HTML
        soup = BeautifulSoup(response.text, "html.parser")

        # រក content
        content = soup.find("div", {"id": "mw-content-text"})
        if not content:
            print("រកមិនឃើញ content!")
            return

        paragraphs = content.find_all("p")

        # បញ្ចូលអត្ថបទទៅ list
        article_text = []
        for p in paragraphs:
            text = p.get_text().strip()
            if text:
                article_text.append(text)

        # បង្ហាញលទ្ធផល
        print("=== Article Preview ===\n")
        for line in article_text[:5]:  # បង្ហាញតែ 5 paragraph ដំបូង
            print(line + "\n")

        # រក្សាទុកជា file
        with open(output_file, "w", encoding="utf-8") as f:
            for line in article_text:
                f.write(line + "\n\n")

        print(f"\n✅ បានរក្សាទុកជា {output_file}")

    except requests.exceptions.RequestException as e:
        print("Error:", e)


# 🔹 URL អត្ថបទ Wikipedia
url = "https://km.wikipedia.org/wiki/%E1%9E%80%E1%9E%B6%E1%9E%9A%E1%9E%82%E1%9F%92%E1%9E%9A%E1%9E%94%E1%9F%8B%E1%9E%82%E1%9F%92%E1%9E%9A%E1%9E%84%E1%9E%9A%E1%9E%94%E1%9E%9F%E1%9F%8B%E1%9E%81%E1%9F%92%E1%9E%98%E1%9F%82%E1%9E%9A%E1%9E%80%E1%9F%92%E1%9E%9A%E1%9E%A0%E1%9E%98%E1%9E%93%E1%9F%85%E1%9E%80%E1%9E%98%E1%9F%92%E1%9E%96%E1%9E%BB%E1%9E%87%E1%9E%B6"

# 🔹 ហៅ function
fetch_wikipedia_article(url)
# Out:
# === Article Preview ===
#
# @,
#
# សម័យខ្មែរក្រហម (១៩៧៥-១៩៧៩) ដែលសំដៅលើការដឹកនាំគ្រប់គ្រងដោយប៉ុល-ពត
#
# កំឡុងពេល៤ឆ្នាំ បានធ្វើអោយឃើញនូវមរណភាពនៃប្រជាជនខ្មែរប្រហែលពីរលាននាក់តាមរយៈលទ្ធផលរួមផ្សំ នៃការសម្លាប់ខាងនយោបាយ ការអត់ឃ្លាន និងការធ្វើការដោយបង្ខំ ។[១][២]  ដោយសារតែចំនួនដ៏ច្រើននេះ មរណភាពកំឡុងការដឹកនាំគ្រប់គ្រងរបស់ពួកខ្មែរក្រហម​ដែលជានិច្ចកាល គេបានចាត់ទុកថាជាការប្រល័យពូជសាសន៍ និងត្រូវគេស្គាល់ជាទូទៅថាជា ហាយនភាពខ្មែរ រឺ ការប្រល័យពូជសាសន៍ខ្មែរ ។
# សម័យខ្មែរក្រហមបានបញ្ចប់ជាមួយការលុកលុយកម្ពុជាដោយសម្ព័ន្ធមិត្តជិតខាង និងកាលពីអតីត គឺវៀតណាមក្នុងសង្គ្រាមកម្ពុជា-វៀតណាម ដែលទុកអោយកម្ពុជាក្រោមការកាន់កាប់របស់វៀតណាមអស់មួយទសវ     ត្ស ។
#
# ដោយសារជ័យជំនះកម្មុយនិស្តខែ មេសា ១៩៧៥ ប៉ុល-ពត និងពួកសហការីជិតស្និទរបស់គាត់បានកាន់កាប់តំណែងសំខាន់ៗបំផុត​នៅក្នុងបក្សកុម្មុយនិស្តកម្ពុជា (ប.ក.ក.) និងនៅក្នុងឋានានុក្រមរដ្ឋ ។ គាត់ធ្លាប់ជាលេខាប.ក.ក. (អគ្គលេខាធិការ) តាំងពីខែ កុម្ភៈ ១៩៦៣ មកម៉្លេះ ។ ពួកសហការីរបស់គាត់ធ្លាប់មានតួនាទីជាទីភ្នាក់ងារនយោបាយរបស់បក្ស ហើយពួកគេបានក្ដោបក្ដាប់កៅអីភាគច្រើននៅឯគណៈមជ្ឍិម ។
#
# ពេញមួយទសវត្សឆ្នាំ១៩៧០ និងជាពិសេសបន្ទាប់ពីopពាក់កណ្ដាលឆ្នាំ១៩៧៥ បក្សនេះត្រូវរង្គោះរង្គើដោយការដណ្ដើមបក្សពួកគ្នា ។ ថែមទាំងមានការប៉ុនប៉ងប្រដាប់អាវុធដើម្បីផ្ដួលរំលំប៉ុល-ពតថែមទៀតផង ។ បន្សុទ្ធកម្មជាលទ្ធផលបានឈានដល់ចំណុចកំពូលនៅឆ្នាំ១៩៧៧ និង ១៩៧៨ ដែលនៅពេលនោះប្រជាជនរាប់រយពាន់នាក់ រួមទាំងភាគខ្លះនៃពួកមេដឹកនាំប.ក.ក.ដ៏សំខាន់ៗបំផុត ក៏ត្រូវបានគេប្រហារជីវិតដែរ ។CAMBODIA
#
#
# ✅ បានរក្សាទុកជា wikipedia1.txt

# %% [markdown]
# ### setup env

# %%
# !pip install nltk numpy pandas
# Out:
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.9.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install khmer-nltk
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting khmer-nltk
#   Using cached khmer_nltk-1.6-py3-none-any.whl.metadata (6.9 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting sklearn-crfsuite (from khmer-nltk)
#   Using cached sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from khmer-nltk) (4.67.3)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->khmer-nltk)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.3 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting scikit-learn>=0.24.0 (from sklearn-crfsuite->khmer-nltk)
#   Downloading scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting tabulate>=0.4.2 (from sklearn-crfsuite->khmer-nltk)
#   Using cached tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: numpy>=1.24.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.5.3)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting threadpoolctl>=3.2.0 (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached khmer_nltk-1.6-py3-none-any.whl (7.0 MB)
# Using cached sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-macosx_11_0_arm64.whl (319 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 9.9 MB/s  0:00:00m eta 0:00:01
# Using cached tabulate-0.10.0-py3-none-any.whl (39 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, tabulate, python-crfsuite, scikit-learn, sklearn-crfsuite, khmer-nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [khmer-nltk]6 [scikit-learn]
# Successfully installed khmer-nltk-1.6 python-crfsuite-0.9.12 scikit-learn-1.8.0 sklearn-crfsuite-0.5.0 tabulate-0.10.0 threadpoolctl-3.6.0

# %% [markdown]
# ### cleaning Text

# %%
import re
def clean_text(text):
    text = re.sub(r"[^\u1780-\u17FF\s]", "", text)
    return text 
with open("wikipedia1.txt","r", encoding="utf-8") as f:
    text = clean_text(f.read())

# %%
# !pip install khmer-nltk
# Out:
# Requirement already satisfied: khmer-nltk in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.6)
# Requirement already satisfied: sklearn-crfsuite in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from khmer-nltk) (0.5.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from khmer-nltk) (4.67.3)
# Requirement already satisfied: python-crfsuite>=0.9.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sklearn-crfsuite->khmer-nltk) (0.9.12)
# Requirement already satisfied: scikit-learn>=0.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sklearn-crfsuite->khmer-nltk) (1.8.0)
# Requirement already satisfied: tabulate>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sklearn-crfsuite->khmer-nltk) (0.10.0)
# Requirement already satisfied: numpy>=1.24.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite->khmer-nltk) (3.6.0)

# %% [markdown]
# ### khmer tokenizer

# %%
from khmernltk import word_tokenize
tokens = word_tokenize(text)
print(tokens[:20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from khmernltk import word_tokenize
#       2 tokens = word_tokenize(text)
#       3 print(tokens[:20])
#
# ModuleNotFoundError: No module named 'khmernltk'

# %% [markdown]
# ### Vocabulary + < UNK >

# %%
from collections import Counter

freq = Counter(tokens)
vocab = {w for w,c in freq.items() if c >= 2}
# vocabulary + <UNK>
vocab.add("<UNK>")
print(f"Vocabulary size: {len(vocab)}")
# Out:
# Vocabulary size: 856

# %% [markdown]
# ### splite Dataset(70/10/20)

# %%
n = len(tokens)

train = tokens[:int(0.7*n)]
test = tokens[int(0.8*n):]
val = tokens[int(0.7 * n):int(0.8 * n)]

#cheak verify size
print(f"Train size: {len(train)}")
print(f"Test size: {len(test)}")
print(f"Validation size: {len(val)}")
# Out:
# Train size: 6886
# Test size: 1968
# Validation size: 984

# %% [markdown]
# ### create N-gram

# %%
from collections import Counter

def build_ngrams(tokens, n):
    return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

# build ngrams
train_4 = build_ngrams(train, 4)
train_3 = build_ngrams(train, 3)
train_2 = build_ngrams(train, 2)

# count
count_4 = Counter(train_4)
count_3 = Counter(train_3)
count_2 = Counter(train_2)
count_1 = Counter(train)

# %% [markdown]
# ### LM1 – Backoff Model

# %%
def backoff_prob(w1, w2, w3, w4):
    if count_3[(w1,w2,w3)] > 0 and count_4[(w1,w2,w3,w4)] > 0:
        return count_4[(w1,w2,w3,w4)] / count_3[(w1,w2,w3)]

    elif count_2[(w2,w3)] > 0 and count_3[(w2,w3,w4)] > 0:
        return count_3[(w2,w3,w4)] / count_2[(w2,w3)]

    elif count_1[w3] > 0 and count_2[(w3,w4)] > 0:
        return count_2[(w3,w4)] / count_1[w3]

    else:
        return count_1[w4] / len(train)
## best model (unsmoothed)

# %% [markdown]
# ### LM2 – Interpolation + Add-k

# %%
# add-k smoothing
def smoothed_prob(count_ngram, count_prev, V, k=0.01):
    return (count_ngram + k) / (count_prev + k*V)

# %%
# interpolation
lambda1, lambda2, lambda3, lambda4 = 0.25, 0.25, 0.25, 0.25
V = len(vocab)

def interpolated_prob(w1, w2, w3, w4):
    p4 = smoothed_prob(count_4[(w1,w2,w3,w4)], count_3[(w1,w2,w3)], V)
    p3 = smoothed_prob(count_3[(w2,w3,w4)], count_2[(w2,w3)], V)
    p2 = smoothed_prob(count_2[(w3,w4)], count_1[w3], V)
    p1 = smoothed_prob(count_1[w4], len(train), V)
    return lambda1*p4 + lambda2*p3 + lambda3*p2 + lambda4*p1

# %% [markdown]
# ### Perplexity Evaluation

# %%
import math

def perplexity(model, tokens):
    N = len(tokens)
    log_prob = 0

    for i in range(3, N):
        w1,w2,w3,w4 = tokens[i-3], tokens[i-2], tokens[i-1], tokens[i]
        p = model(w1,w2,w3,w4)

        if p == 0:
            p = 1e-10  

        log_prob += math.log(p)

    return math.exp(-log_prob / N)

# %%
pp_backoff = perplexity(backoff_prob, test)
pp_interpolated = perplexity(interpolated_prob, test)
print(f"Backoff Perplexity: {pp_backoff}")
print(f"Interpolated Perplexity: {pp_interpolated}")
# Out:
# Backoff Perplexity: 2063.555031455442
# Interpolated Perplexity: 242.95779359560905

# %% [markdown]
# ### Text Generation

# %%
import random

def generate(model, seed, length=20):
    result = seed[:]

    for _ in range(length):
        w1,w2,w3 = result[-3:]
        candidates = list(vocab)

        probs = [model(w1,w2,w3,w) for w in candidates]
        next_word = random.choices(candidates, weights=probs)[0]

        result.append(next_word)

    return " ".join(result)

# %%
print(generate(interpolated_prob, ["កាត់","សម្លាប់","ភាសា"]))
# Out:
# កាត់ សម្លាប់ ភាសា វាល មន្ទីរ ទំនើប ម្នាក់ អាហារ រដ្ឋមន្ត្រី រូប អង្គភាព របស់   ទីក្រុង កណ្ដាល ព័ត៌មាន ក្រុម ជានិច្ចកាល ដូច្នេះហើយ អញ្ជឹង មួយ ផ្ដាច់ការ ដែក
